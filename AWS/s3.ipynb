# %%
import os
print(os.getcwd())
# Out:
# c:\Users\user\Desktop\work\Profile\AWS

# %%
import pprint
import random
import string

import boto3

print("📚 Setting up the environment...")

# Initialize pretty printer for better output formatting
pp = pprint.PrettyPrinter(indent=2)

# Create S3 client using default credentials from AWS CLI
# boto3 will automatically use credentials from ~/.aws/credentials
os.environ["AWS_SHARED_CREDENTIALS_FILE"] = os.path.abspath("../.aws/credentials")
os.environ["AWS_CONFIG_FILE"] = os.path.abspath("../.aws/config")

s3 = boto3.client("s3", region_name="eu-west-1")
print("✅ Environment setup complete!")
print(f"🌍 Using AWS region: {s3.meta.region_name}")
# Out:
# 📚 Setting up the environment...
# ✅ Environment setup complete!
# 🌍 Using AWS region: eu-west-1

# %%
#Listing existing s3 Buckets
print("📋 Listing all S3 buckets in your account...")
response = s3.list_buckets()

print("\n📦 Raw response from AWS:")
pp.pprint(response)

print("\n📦 Your current S3 buckets:")
if response["Buckets"]:
    for bucket in response["Buckets"]:
        print(f"- {bucket['Name']}")
else:
    print("No buckets found in your account")

print(f"\n✅ Successfully retrieved {len(response['Buckets'])} buckets")
# Out:
# 📋 Listing all S3 buckets in your account...
#
# 📦 Raw response from AWS:
# { 'Buckets': [ { 'BucketArn': 'arn:aws:s3:::amzn-main-bucket-3',
#                  'CreationDate': datetime.datetime(2026, 9, 4, 11, 55, 4, tzinfo=tzutc()),
#                  'Name': 'amzn-main-bucket-3'}],
#   'Owner': { 'ID': 'b13014acb0c76557b562c7e222cad5698c83ed6456d3f6d78efe6a4e3f00c86b'},
#   'ResponseMetadata': { 'HTTPHeaders': { 'content-type': 'application/xml',
#                                          'date': 'Fri, 04 Sep 2026 12:13:44 '
#                                                  'GMT',
#                                          'server': 'AmazonS3',
#                                          'transfer-encoding': 'chunked',
#                                          'x-amz-id-2': 'gfoa7jQ19VYlTWvnQSjrbvGKXuXKEtVt+ARD12FR8P5j1eS219s9UuIW9+J3pRa5B5rXkYO88JXjpIbTYQwKBX2Nosw4jIBp',
#                                          'x-amz-request-id': 'AGDA7D6NBBB01MAV'},
#                         'HTTPStatusCode': 200,
#                         'HostId': 'gfoa7jQ19VYlTWvnQSjrbvGKXuXKEtVt+ARD12FR8P5j1eS219s9UuIW9+J3pRa5B5rXkYO88JXjpIbTYQwKBX2Nosw4jIBp',
#                         'RequestId': 'AGDA7D6NBBB01MAV',
#                         'RetryAttempts': 0}}
#
# 📦 Your current S3 buckets:
# - amzn-main-bucket-3
#
# ✅ Successfully retrieved 1 buckets

# %% [markdown]
# ### Uploading in S3

# %%
bucket_name = "amzn-main-bucket-3"
print(f"⬆️  Uploading file to bucket: {bucket_name}")

try:
    s3.upload_file("../Data/data_for_analysis/cleaned_data.parquet", bucket_name, "cleaned_data.parquet")
    print("✅ Upload successful!")
    print(f"📍 File location: s3://{bucket_name}/cleaned_data.parquet")
    print(f"ℹ️ Note: The https URL https://{bucket_name}.s3.eu-west-1.amazonaws.com/cleaned_data.parquet")
    print("   won't work directly because S3 objects are private by default!")
    print("   We'll generate a pre-signed URL later to access this file via HTTPS.")

    # Verify the upload by listing objects in the bucket
    objects = s3.list_objects_v2(Bucket=bucket_name)
    print("\n📦 Current bucket contents:")
    for obj in objects.get("Contents", []):
        print(f"- {obj['Key']} ({obj['Size']} bytes)")
except Exception as e:
    print(f"❌ Error uploading file: {str(e)}")
# Out:
# ⬆️  Uploading file to bucket: amzn-main-bucket-3
# ✅ Upload successful!
# 📍 File location: s3://amzn-main-bucket-3/cleaned_data.parquet
# ℹ️ Note: The https URL https://amzn-main-bucket-3.s3.eu-west-1.amazonaws.com/cleaned_data.parquet
#    won't work directly because S3 objects are private by default!
#    We'll generate a pre-signed URL later to access this file via HTTPS.
#
# 📦 Current bucket contents:
# - cleaned_data.parquet (1867896 bytes)
